# %% [markdown]
# <a href="https://colab.research.google.com/github/FelipeTufaile/customer_lifetime_value/blob/main/notebooks/Feature_Processing_Kdd_Cup_98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Dowloading Files

# %%
# %%shell
# wget https://kdd.ics.uci.edu/databases/kddcup98/epsilon_mirror/cup98lrn.zip -P ../content/drive/MyDrive/Colab/Sandbox/Data/
# wget https://kdd.ics.uci.edu/databases/kddcup98/epsilon_mirror/cup98val.zip -P ../content/drive/MyDrive/Colab/Sandbox/Data/
# wget https://kdd.ics.uci.edu/databases/kddcup98/epsilon_mirror/valtargt.txt -P ../content/drive/MyDrive/Colab/Sandbox/Data/
# cd ../content/drive/MyDrive/Colab/Sandbox/Data/
# unzip cup98lrn.zip
# unzip cup98val.zip
# Out:
# --2024-08-06 03:08:51--  https://kdd.ics.uci.edu/databases/kddcup98/epsilon_mirror/cup98lrn.zip
# Resolving kdd.ics.uci.edu (kdd.ics.uci.edu)... 128.195.1.86
# Connecting to kdd.ics.uci.edu (kdd.ics.uci.edu)|128.195.1.86|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36468735 (35M) [application/zip]
# Saving to: ‘../content/drive/MyDrive/Colab/Sandbox/Data/cup98lrn.zip’
#
# cup98lrn.zip        100%[===================>]  34.78M  30.4MB/s    in 1.1s
#
# 2024-08-06 03:08:52 (30.4 MB/s) - ‘../content/drive/MyDrive/Colab/Sandbox/Data/cup98lrn.zip’ saved [36468735/36468735]
#
# --2024-08-06 03:08:52--  https://kdd.ics.uci.edu/databases/kddcup98/epsilon_mirror/cup98val.zip
# Resolving kdd.ics.uci.edu (kdd.ics.uci.edu)... 128.195.1.86
# Connecting to kdd.ics.uci.edu (kdd.ics.uci.edu)|128.195.1.86|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36763018 (35M) [application/zip]
# ...

# %% [markdown]
# ## 2. Importing Libraries

# %%
import pandas as pd

# %% [markdown]
# ## 3. Reading Kdd Cup 98 Data

# %%
df_train = pd.read_csv("../content/drive/MyDrive/Colab/Sandbox/Data/cup98LRN.txt")

df_train
# Out:
# <ipython-input-15-5b72e2c110f2>:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_train = pd.read_csv("../content/drive/MyDrive/Colab/Sandbox/Data/cup98LRN.txt")
#        ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0         8901     GRI      0    IL  61081                    3712      0
# 1         9401     BOA      1    CA  91326                    5202      0
# 2         9001     AMH      1    NC  27017                       0      0
# 3         8701     BRY      0    CA  95953                    2801      0
# 4         8601              0    FL  33176                    2001      0
# ...        ...     ...    ...   ...    ...      ...      ...   ...    ...
# 95407     9601     ASE      1    AK  99504                       0      0
# 95408     9601     DCD      1    TX  77379                    5001      0
# 95409     9501     MBC      1    MI  48910                    3801      0
# ...

# %%
df_eval = pd.read_csv("../content/drive/MyDrive/Colab/Sandbox/Data/cup98VAL.txt")

df_eval
# Out:
# <ipython-input-16-3b74d351b751>:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_eval = pd.read_csv("../content/drive/MyDrive/Colab/Sandbox/Data/cup98VAL.txt")
#        ODATEDW OSOURCE  TCODE STATE     ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0         9301     PV3      0    WI   53558                    1702      0
# 1         9501     CNT      0    TX   78501                    1501      0
# 2         9101     L01      1    CA   92392                    3001      0
# 3         9401     HAM      0    TX  77625-                    4909      0
# 4         9201     NAS      2    TX   76051                    5406      0
# ...        ...     ...    ...   ...     ...      ...      ...   ...    ...
# 96362     9201     HPS      1    TN   37620                    1901      0
# 96363     9201     AGR      1    WI   53235                    4310      0
# 96364     9601     AGR      1    MN   55122                    4601      0
# ...

# %%
num_train = df_train.shape[0]

df_eval_target = pd.read_csv('/tmp/lifetime-value/kdd_cup_98/valtargt.txt')
df_eval = df_eval.merge(df_eval_target, on='CONTROLN')
